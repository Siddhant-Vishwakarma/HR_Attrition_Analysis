# %%
import pandas as pd
import numpy as np

# %%
employees = pd.read_excel("HR_Analytics_Uncleaned_Dataset.xlsx",sheet_name = "Employees")
attendance = pd.read_excel("HR_Analytics_Uncleaned_Dataset.xlsx",sheet_name = "Attendance")
performance = pd.read_excel("HR_Analytics_Uncleaned_Dataset.xlsx",sheet_name = "Performance")

# %%
employees.head()
# Out:
#    EmployeeID        Name Department    JobRole    HireDate Gender  Salary  \
# 0           1  Employee 1         HR    Analyst  2018-03-22      M   80505
# 1           2  Employee 2         HR  Associate  2023-10-16      F   77368
# 2           3  Employee 3         IT    Analyst  2023-07-09      M   33198
# 3           4  Employee 4      Sales    Analyst  2022-12-18      M   87655
# 4           5  Employee 5    Finance  Executive  2022-05-24      F   28962
#
#    ManagerID             Email
# 0         38  emp1@company.com
# 1         29  emp2@company.com
# 2         63  emp3@company.com
# 3         78  emp4@company.com
# 4         13  emp5@company.com

# %%
attendance.head()
# Out:
#    AttendanceID  EmployeeID        Date   Status  WorkHours
# 0             1          37  12/05/2025      WFH        7.7
# 1             2         412  01/02/2025    Leave        NaN
# 2             3         865  13/01/2025  Present        8.8
# 3             4         200  02/06/2025      WFH        6.0
# 4             5         725  23/02/2025  Present        9.6

# %%
performance.head()
# Out:
#    ReviewID  EmployeeID  ReviewDate  PerformanceScore  TrainingHours  \
# 0         1           1  2025-06-30               5.0             23
# 1         2           2  2025-06-30               NaN             61
# 2         3           3  2025-06-30               5.0             75
# 3         4           4  2025-06-30               1.0             65
# 4         5           5  2025-06-30               2.0              7
#
#   Promotion Attrition
# 0       Yes        No
# 1        No        No
# 2       Yes        No
# 3        No        No
# 4       Yes       Yes

# %%
# describe employees data
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EmployeeID  1001 non-null   int64
#  1   Name        1001 non-null   object
#  2   Department  1001 non-null   object
#  3   JobRole     1001 non-null   object
#  4   HireDate    1001 non-null   object
#  5   Gender      1001 non-null   object
#  6   Salary      1001 non-null   int64
#  7   ManagerID   1001 non-null   int64
#  8   Email       954 non-null    object
# dtypes: int64(3), object(6)
# memory usage: 70.5+ KB

# %%
employees.describe()
# Out:
#         EmployeeID         Salary    ManagerID
# count  1001.000000    1001.000000  1001.000000
# mean    500.004995   87641.604396    50.342657
# std     289.099507   35586.909360    29.060342
# min       1.000000   25008.000000     1.000000
# 25%     250.000000   58423.000000    24.000000
# 50%     500.000000   86991.000000    51.000000
# 75%     750.000000  118736.000000    76.000000
# max    1000.000000  149942.000000   100.000000

# %%
# column name
employees.columns
# Out:
# Index(['EmployeeID', 'Name', 'Department', 'JobRole', 'HireDate', 'Gender',
#        'Salary', 'ManagerID', 'Email'],
#       dtype='object')

# %%
# check null values if existis
employees.isnull().sum()
# Out:
# EmployeeID     0
# Name           0
# Department     0
# JobRole        0
# HireDate       0
# Gender         0
# Salary         0
# ManagerID      0
# Email         47
# dtype: int64

# %%
employees.columns
# Out:
# Index(['EmployeeID', 'Name', 'Department', 'JobRole', 'HireDate', 'Gender',
#        'Salary', 'ManagerID', 'Email'],
#       dtype='object')

# %%
# delete email column if not required
employees.drop("Email",axis = 1 , inplace = True)

# %%
# check datatypes
employees.dtypes
# Out:
# EmployeeID     int64
# Name          object
# Department    object
# JobRole       object
# HireDate      object
# Gender        object
# Salary         int64
# ManagerID      int64
# dtype: object

# %%
# convert data type of HireDate column to date
employees["HireDate"] = pd.to_datetime(employees["HireDate"])

# %%
# check data types after formatting
employees.dtypes
# Out:
# EmployeeID             int64
# Name                  object
# Department            object
# JobRole               object
# HireDate      datetime64[ns]
# Gender                object
# Salary                 int64
# ManagerID              int64
# dtype: object

# %%
# check duplicates
employees["EmployeeID"].duplicated().sum()
# Out:
# np.int64(1)

# %%
# remove duplicate based on primary key column
employees.drop_duplicates(subset = ["EmployeeID"],inplace=True)

# %%
# check duplicates after removes duplicates
employees["EmployeeID"].duplicated().sum()
# Out:
# np.int64(0)

# %%
# understand attendance table
attendance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AttendanceID  8000 non-null   int64
#  1   EmployeeID    8000 non-null   int64
#  2   Date          8000 non-null   object
#  3   Status        8000 non-null   object
#  4   WorkHours     7769 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 312.6+ KB

# %%
attendance.describe()
# Out:
#        AttendanceID   EmployeeID    WorkHours
# count    8000.00000  8000.000000  7769.000000
# mean     4000.50000   502.234625     7.006835
# std      2309.54541   288.866841     1.724194
# min         1.00000     1.000000     4.000000
# 25%      2000.75000   250.000000     5.500000
# 50%      4000.50000   502.000000     7.000000
# 75%      6000.25000   754.000000     8.500000
# max      8000.00000  1000.000000    10.000000

# %%
# check null values
attendance.isnull().sum()
# Out:
# AttendanceID      0
# EmployeeID        0
# Date              0
# Status            0
# WorkHours       231
# dtype: int64

# %%
# fill null values
attendance["WorkHours"] = attendance["WorkHours"].fillna(attendance["WorkHours"].mean())

# %%
# after fill null values check dataset
attendance.isnull().sum()
# Out:
# AttendanceID    0
# EmployeeID      0
# Date            0
# Status          0
# WorkHours       0
# dtype: int64

# %%
# check data types
attendance.dtypes
# Out:
# AttendanceID      int64
# EmployeeID        int64
# Date             object
# Status           object
# WorkHours       float64
# dtype: object

# %%
# convert Date column to datetime formate
attendance["Date"] = pd.to_datetime(attendance["Date"],dayfirst= True)

# %%
attendance.dtypes
# Out:
# AttendanceID             int64
# EmployeeID               int64
# Date            datetime64[ns]
# Status                  object
# WorkHours              float64
# dtype: object

# %%
# check duplicate based on AttendanceID
attendance["AttendanceID"].nunique()
# Out:
# 8000

# %%
# understand Performance table
performance.head()
# Out:
#    ReviewID  EmployeeID  ReviewDate  PerformanceScore  TrainingHours  \
# 0         1           1  2025-06-30               5.0             23
# 1         2           2  2025-06-30               NaN             61
# 2         3           3  2025-06-30               5.0             75
# 3         4           4  2025-06-30               1.0             65
# 4         5           5  2025-06-30               2.0              7
#
#   Promotion Attrition
# 0       Yes        No
# 1        No        No
# 2       Yes        No
# 3        No        No
# 4       Yes       Yes

# %%
performance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ReviewID          1000 non-null   int64
#  1   EmployeeID        1000 non-null   int64
#  2   ReviewDate        1000 non-null   object
#  3   PerformanceScore  860 non-null    float64
#  4   TrainingHours     1000 non-null   int64
#  5   Promotion         1000 non-null   object
#  6   Attrition         1000 non-null   object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 54.8+ KB

# %%
# check duplicates values
performance.duplicated().sum()

# %%
# check data types
performance.dtypes

# %%
# merge tables
# first merge
df = pd.merge(
    employees,
    attendance,
    on = "EmployeeID",
    how = "left"
)

# %%
# second merge
df = pd.merge(
    employees,
    performance,
    on = "EmployeeID",
    how = "left"
)

# %%
df.head()
# Out:
#    EmployeeID        Name Department    JobRole   HireDate Gender  Salary  \
# 0           1  Employee 1         HR    Analyst 2018-03-22      M   80505
# 1           2  Employee 2         HR  Associate 2023-10-16      F   77368
# 2           3  Employee 3         IT    Analyst 2023-07-09      M   33198
# 3           4  Employee 4      Sales    Analyst 2022-12-18      M   87655
# 4           5  Employee 5    Finance  Executive 2022-05-24      F   28962
#
#    ManagerID  ReviewID  ReviewDate  PerformanceScore  TrainingHours Promotion  \
# 0         38         1  2025-06-30               5.0             23       Yes
# 1         29         2  2025-06-30               NaN             61        No
# 2         63         3  2025-06-30               5.0             75       Yes
# 3         78         4  2025-06-30               1.0             65        No
# 4         13         5  2025-06-30               2.0              7       Yes
#
#   Attrition
# 0        No
# 1        No
# 2        No
# 3        No
# 4       Yes

# %%
df.columns
# Out:
# Index(['EmployeeID', 'Name', 'Department', 'JobRole', 'HireDate', 'Gender',
#        'Salary', 'ManagerID', 'ReviewID', 'ReviewDate', 'PerformanceScore',
#        'TrainingHours', 'Promotion', 'Attrition'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   EmployeeID        1000 non-null   int64
#  1   Name              1000 non-null   object
#  2   Department        1000 non-null   object
#  3   JobRole           1000 non-null   object
#  4   HireDate          1000 non-null   datetime64[ns]
#  5   Gender            1000 non-null   object
#  6   Salary            1000 non-null   int64
#  7   ManagerID         1000 non-null   int64
#  8   ReviewID          1000 non-null   int64
#  9   ReviewDate        1000 non-null   object
#  10  PerformanceScore  860 non-null    float64
#  11  TrainingHours     1000 non-null   int64
#  12  Promotion         1000 non-null   object
#  13  Attrition         1000 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(5), object(7)
# memory usage: 109.5+ KB

# %%
# remove null values in column Performance Score
df["PerformanceScore"] = df["PerformanceScore"].fillna(df["PerformanceScore"].mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   EmployeeID        1000 non-null   int64
#  1   Name              1000 non-null   object
#  2   Department        1000 non-null   object
#  3   JobRole           1000 non-null   object
#  4   HireDate          1000 non-null   datetime64[ns]
#  5   Gender            1000 non-null   object
#  6   Salary            1000 non-null   int64
#  7   ManagerID         1000 non-null   int64
#  8   ReviewID          1000 non-null   int64
#  9   ReviewDate        1000 non-null   object
#  10  PerformanceScore  1000 non-null   float64
#  11  TrainingHours     1000 non-null   int64
#  12  Promotion         1000 non-null   object
#  13  Attrition         1000 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(5), object(7)
# memory usage: 109.5+ KB

# %%
df["Department"].unique()
# Out:
# array(['HR', 'IT', 'Sales', 'Finance', 'Marketing'], dtype=object)

# %%
df.shape
# Out:
# (1000, 14)

# %%
df.describe()
# Out:
#         EmployeeID                       HireDate         Salary    ManagerID  \
# count  1000.000000                           1000    1000.000000  1000.000000
# mean    500.500000  2021-05-19 09:05:45.600000256   87679.246000    50.383000
# min       1.000000            2018-01-02 00:00:00   25008.000000     1.000000
# 25%     250.750000            2019-09-01 06:00:00   58432.750000    24.000000
# 50%     500.500000            2021-06-20 12:00:00   87037.000000    51.000000
# 75%     750.250000            2023-01-10 06:00:00  118749.000000    76.000000
# max    1000.000000            2024-11-02 00:00:00  149942.000000   100.000000
# std     288.819436                            NaN   35584.773241    29.046825
#
#           ReviewID  PerformanceScore  TrainingHours
# count  1000.000000       1000.000000    1000.000000
# mean    500.500000          3.054651      41.447000
# min       1.000000          1.000000       0.000000
# 25%     250.750000          2.000000      21.000000
# 50%     500.500000          3.054651      42.000000
# 75%     750.250000          4.000000      62.000000
# max    1000.000000          5.000000      80.000000
# std     288.819436          1.303123      23.365255

# %%
#check missing values
df.isnull().sum()
# Out:
# EmployeeID          0
# Name                0
# Department          0
# JobRole             0
# HireDate            0
# Gender              0
# Salary              0
# ManagerID           0
# ReviewID            0
# ReviewDate          0
# PerformanceScore    0
# TrainingHours       0
# Promotion           0
# Attrition           0
# dtype: int64

# %%
# check duplicated values
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# check datatypes
df.dtypes
# Out:
# EmployeeID                   int64
# Name                        object
# Department                  object
# JobRole                     object
# HireDate            datetime64[ns]
# Gender                      object
# Salary                       int64
# ManagerID                    int64
# ReviewID                     int64
# ReviewDate                  object
# PerformanceScore           float64
# TrainingHours                int64
# Promotion                   object
# Attrition                   object
# dtype: object

# %%
# find average salary
avg_salary = df["Salary"].mean()
avg_salary
# Out:
# np.float64(87679.246)

# %%
# find minimum and maximum salary
# 1. minimum salary
min_salary = df["Salary"].min()
min_salary
# Out:
# np.int64(25008)

# %%
# 2. maximum salary
max_salary = df["Salary"].max()
max_salary
# Out:
# np.int64(149942)

# %%
# median salary
median_salary = df["Salary"].median()
median_salary
# Out:
# np.float64(87037.0)

# %%
# job role wise salary
df.groupby("JobRole")["Salary"].mean().sort_values(ascending=False)
# Out:
# JobRole
# Analyst      89661.187251
# Manager      88976.504167
# Associate    86597.628692
# Executive    85648.121324
# Name: Salary, dtype: float64

# %%
# department wise salary
df.groupby("Department")["Salary"].mean().sort_values(ascending=False)
# Out:
# Department
# Finance      89413.558140
# Marketing    87995.638743
# IT           87579.758454
# Sales        86817.384236
# HR           86387.092391
# Name: Salary, dtype: float64

# %%
# performance analysis
# 1. average performance out of 5
df["PerformanceScore"].mean()
# Out:
# np.float64(3.0546511627906976)

# %%
# department wise performance
df.groupby("Department")["PerformanceScore"].mean()
# Out:
# Department
# Finance      3.109697
# HR           2.958215
# IT           3.086799
# Marketing    3.090351
# Sales        3.017390
# Name: PerformanceScore, dtype: float64

# %%
# top 10 employees
df.nlargest(10,"PerformanceScore")
# Out:
#     EmployeeID           Name Department    JobRole   HireDate Gender  Salary  \
# 0            1     Employee 1         HR    Analyst 2018-03-22      M   80505
# 2            3     Employee 3         IT    Analyst 2023-07-09      M   33198
# 23          24    Employee 24      Sales    Analyst 2022-06-08      F   26626
# 26          27    Employee 27         HR  Executive 2019-05-27      F   32312
# 28          29    Employee 29  Marketing  Executive 2020-05-29      F   97079
# 32          33    Employee 33         HR    Analyst 2023-01-23      F   81781
# 54          55    Employee 55    Finance  Executive 2018-01-09      F  118211
# 59          60    Employee 60         HR  Associate 2023-09-15      F   31635
# 66          67    Employee 67         HR  Executive 2022-08-19      F   43974
# 70          71   Employee 71   Marketing  Executive 2024-02-06      M  120642
#
#     ManagerID  ReviewID  ReviewDate  PerformanceScore  TrainingHours  \
# 0          38         1  2025-06-30               5.0             23
# 2          63         3  2025-06-30               5.0             75
# 23         80        24  2025-06-30               5.0             70
# 26         25        27  2025-06-30               5.0             23
# 28         49        29  2025-06-30               5.0              0
# 32         73        33  2025-06-30               5.0             68
# 54          3        55  2025-06-30               5.0             67
# 59         50        60  2025-06-30               5.0             56
# 66         89        67  2025-06-30               5.0             54
# 70         54        71  2025-06-30               5.0             59
#
#    Promotion Attrition
# 0        Yes        No
# 2        Yes        No
# 23       Yes       Yes
# 26       Yes        No
# 28       Yes       Yes
# 32        No        No
# 54       Yes       Yes
# 59       Yes       Yes
# 66       Yes       Yes
# 70        No        No

# %%
# bottom 10 employees
df.nsmallest(10,"PerformanceScore")
# Out:
#     EmployeeID         Name Department    JobRole   HireDate Gender  Salary  \
# 3            4   Employee 4      Sales    Analyst 2022-12-18      M   87655
# 5            6   Employee 6  Marketing    Analyst 2021-04-10      M  139402
# 7            8   Employee 8  Marketing    Manager 2018-08-18      M  100397
# 8            9   Employee 9      Sales  Associate 2023-03-10      F   45399
# 14          15  Employee 15         IT  Associate 2022-07-19      F   89091
# 15          16  Employee 16      Sales  Associate 2024-01-19      M  137624
# 17          18  Employee 18      Sales    Manager 2019-11-02      F   94255
# 21          22  Employee 22      Sales  Associate 2018-08-14      F   28326
# 30          31  Employee 31    Finance    Analyst 2019-12-17      M  141780
# 39          40  Employee 40      Sales    Manager 2024-07-05      F  130497
#
#     ManagerID  ReviewID  ReviewDate  PerformanceScore  TrainingHours  \
# 3          78         4  2025-06-30               1.0             65
# 5          31         6  2025-06-30               1.0             59
# 7          37         8  2025-06-30               1.0             43
# 8          78         9  2025-06-30               1.0             65
# 14         54        15  2025-06-30               1.0             55
# 15         13        16  2025-06-30               1.0             40
# 17         50        18  2025-06-30               1.0             19
# 21         26        22  2025-06-30               1.0              9
# 30          9        31  2025-06-30               1.0             45
# 39         14        40  2025-06-30               1.0             67
#
#    Promotion Attrition
# 3         No        No
# 5         No        No
# 7         No        No
# 8         No       Yes
# 14       Yes       Yes
# 15       Yes        No
# 17        No       Yes
# 21       Yes       Yes
# 30       Yes        No
# 39       Yes        No

# %%
# Training hours analysis
# average training hours
df["TrainingHours"].mean()
# Out:
# np.float64(41.447)

# %%
# department wise training hours
df.groupby("Department")["TrainingHours"].mean()
# Out:
# Department
# Finance      40.023256
# HR           41.510870
# IT           43.357488
# Marketing    42.246073
# Sales        40.197044
# Name: TrainingHours, dtype: float64

# %%
# promotion analysis
# promotion count
df["Promotion"].value_counts()
# Out:
# Promotion
# No     503
# Yes    497
# Name: count, dtype: int64

# %%
# promotion percentage
df["Promotion"].value_counts(normalize=True)*100
# Out:
# Promotion
# No     50.3
# Yes    49.7
# Name: proportion, dtype: float64

# %%
# Dpartment wise promotion
pd.crosstab(df["Department"],df["Promotion"])
# Out:
# Promotion    No  Yes
# Department
# Finance     111  104
# HR           86   98
# IT          109   98
# Marketing    81  110
# Sales       116   87

# %%
# Attrition analysis
# Attrition count
df["Attrition"].value_counts()
# Out:
# Attrition
# No     512
# Yes    488
# Name: count, dtype: int64

# %%
# Attrition percentage
df["Attrition"].value_counts(normalize=True)*100
# Out:
# Attrition
# No     51.2
# Yes    48.8
# Name: proportion, dtype: float64

# %%
# department wise Attrition
pd.crosstab(df["Department"],df["Attrition"])
# Out:
# Attrition    No  Yes
# Department
# Finance     110  105
# HR           84  100
# IT          110   97
# Marketing   101   90
# Sales       107   96

# %%
# gender wise Attrition 
pd.crosstab(df["Gender"],df["Attrition"])
# Out:
# Attrition   No  Yes
# Gender
# F          253  256
# M          259  232

# %%
# hire data analysis
# year
df["HireYear"]= df["HireDate"].dt.year

# %%
# month
df["HireMonth"] = df["HireDate"].dt.month_name()

# %%
# find correlation
df.select_dtypes(include="number").corr()
# Out:
#                   EmployeeID    Salary  ManagerID  ReviewID  PerformanceScore  \
# EmployeeID          1.000000  0.039883  -0.005414  1.000000          0.005635
# Salary              0.039883  1.000000  -0.029890  0.039883         -0.016442
# ManagerID          -0.005414 -0.029890   1.000000 -0.005414          0.050591
# ReviewID            1.000000  0.039883  -0.005414  1.000000          0.005635
# PerformanceScore    0.005635 -0.016442   0.050591  0.005635          1.000000
# TrainingHours      -0.025933 -0.019753  -0.016230 -0.025933         -0.007469
# HireYear            0.003046 -0.032674  -0.013596  0.003046         -0.037510
#
#                   TrainingHours  HireYear
# EmployeeID            -0.025933  0.003046
# Salary                -0.019753 -0.032674
# ManagerID             -0.016230 -0.013596
# ReviewID              -0.025933  0.003046
# PerformanceScore      -0.007469 -0.037510
# TrainingHours          1.000000  0.013948
# HireYear               0.013948  1.000000

# %%
# outlier detection
# salary
Q1 = df["Salary"].quantile(0.25)
Q3 = df["Salary"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

df[(df["Salary"]<lower)|(df["Salary"]>upper)]
# Out:
# Empty DataFrame
# Columns: [EmployeeID, Name, Department, JobRole, HireDate, Gender, Salary, ManagerID, ReviewID, ReviewDate, PerformanceScore, TrainingHours, Promotion, Attrition, HireYear, HireMonth]
# Index: []

# %%
# Highest paying department
df.groupby("Department")["Salary"].mean().sort_values(ascending=False)
# Out:
# Department
# Finance      89413.558140
# Marketing    87995.638743
# IT           87579.758454
# Sales        86817.384236
# HR           86387.092391
# Name: Salary, dtype: float64

# %%
# Highest performing department
df.groupby("Department")["PerformanceScore"].mean().sort_values(ascending= False)
# Out:
# Department
# Finance      3.109697
# Marketing    3.090351
# IT           3.086799
# Sales        3.017390
# HR           2.958215
# Name: PerformanceScore, dtype: float64

# %%
# promotion rate
pd.crosstab(df["Department"],df["Promotion"],normalize="index")*100
# Out:
# Promotion          No        Yes
# Department
# Finance     51.627907  48.372093
# HR          46.739130  53.260870
# IT          52.657005  47.342995
# Marketing   42.408377  57.591623
# Sales       57.142857  42.857143

# %%
# salary vs performance
df.groupby("PerformanceScore")["Salary"].mean()
# Out:
# PerformanceScore
# 1.000000    91836.402516
# 2.000000    84438.500000
# 3.000000    85662.926380
# 3.054651    88433.142857
# 4.000000    89062.275132
# 5.000000    86905.668571
# Name: Salary, dtype: float64
