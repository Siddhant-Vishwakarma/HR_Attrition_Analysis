# %%
import pandas as pd
import mysql.connector

# %%
# create connection
conn = mysql.connector.connect(
    host = "localhost",
    user = "root",
    password = "Siddhantmysql2004",
    database = "HR_DB"
)

# %%
cursor = conn.cursor()

df = pd.read_csv("HR_Dataset_Cleaned.csv")
df = df.where(pd.notnull(df),None)

query = """
INSERT INTO HR_Dataset
(EmployeeID, Name, Department, JobRole, HireDate, Gender,
 Salary, ManagerID, ReviewID, ReviewDate,
 PerformanceScore, TrainingHours, Promotion,
 Attrition, HireYear, HireMonth)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

# %%
data = [tuple(row) for row in df.to_numpy()]

cursor.executemany(query, data)

conn.commit()

print(f"{cursor.rowcount} rows inserted successfully!")

cursor.close()
conn.close()
# Out:
# 1000 rows inserted successfully!
